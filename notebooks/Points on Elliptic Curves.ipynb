# %% [markdown]
# # Points on Elliptic Curves

# %% [markdown]
# ![img2](https://p190.p3.n0.cdn.getcloudapp.com/items/YEuoJ9v0/Screen%20Shot%202020-09-05%20at%201.37.39%20AM.png?v=e74c8d123b87f9b38c306bd66cf4e8a1)

# %%
F = GF(11)
E = EllipticCurve(F, [10, 2])
E
# Out:
# Elliptic Curve defined by y^2 = x^3 + 10*x + 2 over Finite Field of size 11

# %% [markdown]
# $ (0 : 1 : 0) $ or $ (x : y : 1) $

# %%
E(0)
# Out:
# (0 : 1 : 0)

# %%
E.points()
# Out:
# [(0 : 1 : 0), (3 : 2 : 1), (3 : 9 : 1), (5 : 1 : 1), (5 : 10 : 1), (6 : 5 : 1), (6 : 6 : 1), (8 : 0 : 1)]

# %%
E(3, 2)
# Out:
# (3 : 2 : 1)

# %%
E.lift_x(3)
# Out:
# (3 : 2 : 1)

# %%
P1 = E(3, 9)
P2 = E(6, 5)
P1 + P2
# Out:
# (5 : 1 : 1)

# %%
3*P1
# Out:
# (5 : 1 : 1)

# %%
C = E.plot(xmin=-10, xmax=10, ymin=-10, ymax=10)
C
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
F = GF(97)
E = EllipticCurve(F, [10, 2])
C = E.plot(xmax=100, ymax=100)
C
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## Reference
#
# - [1] https://blog.cloudflare.com/a-relatively-easy-to-understand-primer-on-elliptic-curve-cryptography/
# - [2] https://doc.sagemath.org/html/en/reference/curves/sage/schemes/elliptic_curves/constructor.html
# - [3] https://doc.sagemath.org/html/en/reference/curves/sage/schemes/elliptic_curves/ell_point.html
# - [4] https://graui.de/code/elliptic2/
